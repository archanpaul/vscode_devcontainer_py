# %%
import sys
print(sys.version)

# %conda list
# %pip list
# Out:
# 3.12.11 | packaged by conda-forge | (main, Jun  4 2025, 14:45:31) [GCC 13.3.0]
# # packages in environment at /opt/conda/envs/venv:
# #
# # Name                                  Version          Build                         Channel
# _openmp_mutex                           4.5              4_kmp_llvm                    conda-forge
# _x86_64-microarch-level                 3                2_skylake
# absl-py                                 2.3.1            pyhd8ed1ab_0                  conda-forge
# adjusttext                              1.3.0            pyhd8ed1ab_0                  conda-forge
# alsa-lib                                1.2.14           h5eee18b_0
# anyio                                   4.11.0           pyhcf101f3_0                  conda-forge
# aom                                     3.9.1            hac33072_0                    conda-forge
# argon2-cffi                             25.1.0           pyhd8ed1ab_0                  conda-forge
# ...
